# %%
import pandas as pd
import requests
import pprint as pprint

base_url = 'https://chronicdata.cdc.gov/resource/hn4x-zwk7.json' 

#parameters = 'topic={topic}'

    #22u52grxdn6zf3isrzr5anpfl
    
    #3fbktuw4m4ckxp7vdw3buzz3utdw8jaeo8vr1aesecln0skfme
    
    # documentation : https://dev.socrata.com/foundry/chronicdata.cdc.gov/hn4x-zwk7

#topic =

# %%
response = requests.get(base_url).json()

response
# Out:
# [{'yearstart': '2018',
#   'yearend': '2018',
#   'locationabbr': 'AL',
#   'locationdesc': 'Alabama',
#   'datasource': 'Behavioral Risk Factor Surveillance System',
#   'class': 'Physical Activity',
#   'topic': 'Physical Activity - Behavior',
#   'question': 'Percent of adults who engage in no leisure-time physical activity',
#   'data_value_type': 'Value',
#   'data_value': '22.2',
#   'data_value_alt': '22.2',
#   'low_confidence_limit': '17',
#   'high_confidence_limit': '28.5',
#   'sample_size': '306',
#   'age_years': '18 - 24',
#   'geolocation': {'latitude': '32.84057112200048',
#    'longitude': '-86.63186076199969',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'classid': 'PA',
#   'topicid': 'PA1',
#   'questionid': 'Q047',
#   'datavaluetypeid': 'VALUE',
#   'locationid': '01',
#   'stratificationcategory1': 'Age (years)',
#   'stratification1': '18 - 24',
#   'stratificationcategoryid1': 'AGEYR',
# ...
