# %%
# Dependencies and Setup
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# File to Load
file_path = "Resources/sugar_per_person_g_per_day.csv"

# Read Purchasing File and store into Pandas data frame
sugar_intake= pd.read_csv(file_path)

sugar_intake.head()
# Out:
#                country   1993   1994   1995   1996   1997   1998  1999   2000  \
# 0          Afghanistan   9.12   8.22   8.45   7.24   7.85   8.34   8.9   8.74
# 1              Albania  76.10  97.50  54.40  63.00  61.70  57.00  56.5  63.40
# 2              Algeria  74.30  71.20  70.60  71.90  76.30  52.40  58.9  78.60
# 3               Angola  25.30  20.80  23.50  26.10  31.70  29.10  34.9  26.50
# 4  Antigua and Barbuda  82.20  86.70  89.30  88.10  85.90  89.40  87.5  86.60
#
#    2001  ...  2004  2005  2006  2007   2008   2009   2010   2011   2012   2013
# 0   8.4  ...  15.5  18.6  19.7  20.8   23.4   23.3   24.3   24.8   25.4   24.5
# 1  66.6  ...  55.0  58.6  67.2  75.5  102.0  117.0  113.0  122.0  129.0  131.0
# 2  77.4  ...  84.3  75.5  77.9  86.7   78.5   85.3   85.6   74.9   82.8   78.2
# 3  29.4  ...  39.3  37.1  38.3  39.5   44.1   40.2   38.9   40.1   42.7   44.7
# 4  86.7  ...  93.1  79.7  85.0  87.3   89.2   87.6   87.6   79.6   87.9   90.1
#
# [5 rows x 22 columns]

# %%
#create table with last 3 years
sugar_intake_2011 = sugar_intake[['country','2011']]
sugar_intake_2012 = sugar_intake[['country','2012']]
sugar_intake_2013 = sugar_intake[['country','2013']]

# %%
top_2011 = sugar_intake_2011.nlargest(3, ['2011']) 
top_2012 = sugar_intake_2012.nlargest(3, ['2012']) 
top_2013 = sugar_intake_2013.nlargest(3, ['2013'])

# %%
top_combine = pd.merge(top_2011, top_2012, how='outer', on='country')
top_combine = pd.merge(top_combine, top_2013, how='outer', on='country').reset_index(drop=True) 
top_combine.set_index('country',inplace=True)
top_combine
# Out:
#                 2011   2012   2013
# country
# United States  172.0  174.0  175.0
# Malta          165.0  168.0  168.0
# Switzerland    160.0  165.0  166.0

# %%
top_combine.plot(kind='bar')

# Give the chart a title, x label, and y label
plt.title("Top 3 Countries with highest sugar intake")
plt.xlabel("Country")
plt.ylabel("Average grams per day")
# Out:
# Text(0, 0.5, 'Average grams per day')

# %%
#10 years of sugar content 
sugar_overtime = sugar_intake[['country','2004','2005','2006','2007','2008','2009','2010','2011','2012','2013']]
