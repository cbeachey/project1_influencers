# %%
# %run SugarVsIncome.ipynb


# %run groceries_final.ipynb
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\IPython\core\magics\execution.py in run(self, parameter_s, runner, file_finder)
#     696             fpath = arg_lst[0]
# --> 697             filename = file_finder(fpath)
#     698         except IndexError:
#
# ~\anaconda3\lib\site-packages\IPython\utils\path.py in get_py_filename(name, force_win32)
#     108     else:
# --> 109         raise IOError('File `%r` not found.' % name)
#     110
#
# OSError: File `'Obesity_vs_SugarConsumption.ipynb.py'` not found.
#
# During handling of the above exception, another exception occurred:
#
# Exception                                 Traceback (most recent call last)
# <ipython-input-20-6eed4c6af000> in <module>
#       5
#       6
# ----> 7 get_ipython().run_line_magic('run', 'Obesity_vs_SugarConsumption.ipynb')
#       8
#
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\IPython\core\magics\execution.py in run(self, parameter_s, runner, file_finder)
#     696             fpath = arg_lst[0]
# --> 697             filename = file_finder(fpath)
#     698         except IndexError:
#
# ~\anaconda3\lib\site-packages\IPython\utils\path.py in get_py_filename(name, force_win32)
#     108     else:
# --> 109         raise IOError('File `%r` not found.' % name)
#     110
#
# OSError: File `'Obesity_vs_SugarConsumption.ipynb.py'` not found.
#
# During handling of the above exception, another exception occurred:
#
# Exception                                 Traceback (most recent call last)
# <ipython-input-21-0f7bec1943af> in <module>
# ----> 1 get_ipython().run_line_magic('run', 'Obesity_vs_SugarConsumption.ipynb')
#
# ...
