# %%
! pip install fatsecret
# Out:
# ...
#   Created wheel for fatsecret: filename=fatsecret-0.2.3-py3-none-any.whl size=8271 sha256=4fa76d4b78e9acc05c23e0e21fb630799bd08eb457f08dfda5f91c74a4656635
#   Stored in directory: c:\users\hilla\appdata\local\pip\cache\wheels\a8\b9\d9\cf912ed488baa3d2de9d77561c5420698077ef2f6197546bc9
# ...
#   Created wheel for rauth: filename=rauth-0.7.3-py3-none-any.whl size=16062 sha256=691c86ada0ef87c829533ec633de1aa7df655350169d3e54b73a2bc1f68b83b1
#   Stored in directory: c:\users\hilla\appdata\local\pip\cache\wheels\72\7a\33\ad03f8d424e1ca6e8e53da0cea1849596ca9b7ab7ecf0b3c5d
# Successfully built fatsecret rauth
# ...

# %%
from fatsecret import Fatsecret

# %%
consumer_key= '761c5bd0812c4af1938fb46132696873'
consumer_secret='01b745597fc14659892bfe9fe141e276'

fs = Fatsecret(consumer_key, consumer_secret)

# %%
foods = fs.foods_search("Soda")
foods
# Out:
# [{'food_description': 'Per 100g - Calories: 38kcal | Fat: 0.01g | Carbs: 9.77g | Protein: 0.07g',
#   'food_id': '387673',
#   'food_name': 'Soda',
#   'food_type': 'Generic',
#   'food_url': 'https://www.fatsecret.com/calories-nutrition/generic/soda'},
#  {'brand_name': 'Pepsi',
#   'food_description': 'Per 8 fl oz - Calories: 100kcal | Fat: 0.00g | Carbs: 28.00g | Protein: 0.00g',
#   'food_id': '76090',
#   'food_name': 'Pepsi',
#   'food_type': 'Brand',
#   'food_url': 'https://www.fatsecret.com/calories-nutrition/pepsi/pepsi'},
#  {'brand_name': 'Sunkist',
#   'food_description': 'Per 1 can - Calories: 160kcal | Fat: 0.00g | Carbs: 44.00g | Protein: 0.00g',
#   'food_id': '62638',
#   'food_name': 'Orange Soda (Can)',
#   'food_type': 'Brand',
#   'food_url': 'https://www.fatsecret.com/calories-nutrition/sunkist/orange-soda-(can)'},
#  {'food_description': 'Per 100g - Calories: 38kcal | Fat: 0.02g | Carbs: 9.78g | Protein: 0.07g',
#   'food_id': '7494',
# ...

# %%
food_get = fs.food_get('387673')
food_get
# Out:
# {'food_id': '387673',
#  'food_name': 'Soda',
#  'food_type': 'Generic',
#  'food_url': 'https://www.fatsecret.com/calories-nutrition/generic/soda',
#  'servings': {'serving': [{'calcium': '0',
#     'calories': '12',
#     'carbohydrate': '3.03',
#     'cholesterol': '0',
#     'fat': '0',
#     'fiber': '0',
#     'iron': '0',
#     'measurement_description': 'fl oz',
#     'metric_serving_amount': '31.000',
#     'metric_serving_unit': 'g',
#     'monounsaturated_fat': '0',
#     'number_of_units': '1.000',
#     'polyunsaturated_fat': '0',
#     'potassium': '0',
#     'protein': '0.02',
#     'saturated_fat': '0',
#     'serving_description': '1 fl oz',
#     'serving_id': '419105',
#     'serving_url': 'https://www.fatsecret.com/calories-nutrition/generic/soda?portionid=419105&portionamount=1.000',
#     'sodium': '2',
#     'sugar': '2.84',
#     'vitamin_a': '0',
#     'vitamin_c': '0'},
#    {'calcium': '0',
#     'calories': '140',
#     'carbohydrate': '36.05',
# ...

# %%
import matplotlib.pyplot as plt
import requests
from scipy import stats
import pandas as pd
from config import api_key

# %%
# Save config information.
#url = "https://platform.fatsecret.com/rest/server.api?"
#method = "food.get.v2"
#food_id = 

# Build partial query URL
#query_url = f"{url}oauth_consumer_key={api_key}&units={units}&q="
