# %%
#! easy_install fatsecret

# %%
#! pip install fatsecret

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
from pprint import pprint
from fatsecret import Fatsecret
#from config import api_key - to put in git ignore.

# %%
consumer_key='a12a75d9e9d249a1ba18e07b67f05510'
consumer_secret='9b337097f25c44ba9eca8a7a9a6857e0'

# %%
fs=Fatsecret(consumer_key, consumer_secret)

# %%
pprint(fs.foods_search("sodas"))
# Out:
# [{'brand_name': 'Mountain Dew',
#   'food_description': 'Per 8 fl oz - Calories: 110kcal | Fat: 0.00g | Carbs: '
#                       '31.00g | Protein: 0.00g',
#   'food_id': '41511',
#   'food_name': 'Mountain Dew',
#   'food_type': 'Brand',
#   'food_url': 'https://www.fatsecret.com/calories-nutrition/mountain-dew/mountain-dew'},
#  {'brand_name': 'Coca-Cola',
#   'food_description': 'Per 1 can - Calories: 140kcal | Fat: 0.00g | Carbs: '
#                       '39.00g | Protein: 0.00g',
#   'food_id': '135673',
#   'food_name': 'Coca-Cola Classic (100 Calorie)',
#   'food_type': 'Brand',
#   'food_url': 'https://www.fatsecret.com/calories-nutrition/coca-cola/coca-cola-classic-(100-calorie)'},
#  {'brand_name': 'Coca-Cola',
#   'food_description': 'Per 1 can - Calories: 140kcal | Fat: 0.00g | Carbs: '
#                       '38.00g | Protein: 0.00g',
#   'food_id': '62739',
#   'food_name': 'Sprite',
#   'food_type': 'Brand',
#   'food_url': 'https://www.fatsecret.com/calories-nutrition/coca-cola/sprite'},
#  {'brand_name': 'Coca-Cola',
#   'food_description': 'Per 1 bottle - Calories: 0kcal | Fat: 0.00g | Carbs: '
#                       '0.00g | Protein: 0.00g',
#   'food_id': '48643',
#   'food_name': 'Coke Zero (20 oz)',
#   'food_type': 'Brand',
#   'food_url': 'https://www.fatsecret.com/calories-nutrition/coca-cola/coke-zero-(20-oz)/1-bottle'},
#  {'brand_name': 'Mountain Dew',
#   'food_description': 'Per 1 can - Calories: 170kcal | Fat: 0.00g | Carbs: '
#                       '46.00g | Protein: 0.00g',
#   'food_id': '54906',
#   'food_name': 'Mountain Dew (12 oz)',
#   'food_type': 'Brand',
#   'food_url': 'https://www.fatsecret.com/calories-nutrition/mountain-dew/mountain-dew-(12-oz)/1-can'},
#  {'brand_name': 'Pepsi',
#   'food_description': 'Per 8 fl oz - Calories: 100kcal | Fat: 0.00g | Carbs: '
#                       '28.00g | Protein: 0.00g',
#   'food_id': '76090',
#   'food_name': 'Pepsi',
#   'food_type': 'Brand',
#   'food_url': 'https://www.fatsecret.com/calories-nutrition/pepsi/pepsi'},
#  {'brand_name': 'Blue Sky',
#   'food_description': 'Per 1 can - Calories: 170kcal | Fat: 0.00g | Carbs: '
#                       '46.00g | Protein: 0.00g',
#   'food_id': '88136',
#   'food_name': 'Natural Cream Soda',
#   'food_type': 'Brand',
#   'food_url': 'https://www.fatsecret.com/calories-nutrition/blue-sky/natural-cream-soda'},
#  {'brand_name': 'Coca-Cola',
#   'food_description': 'Per 8 fl oz - Calories: 0kcal | Fat: 0.00g | Carbs: '
#                       '0.00g | Protein: 0.00g',
#   'food_id': '90946',
#   'food_name': 'Diet Coke',
#   'food_type': 'Brand',
#   'food_url': 'https://www.fatsecret.com/calories-nutrition/coca-cola/diet-coke'},
#  {'brand_name': "Arby's",
#   'food_description': 'Per 1 serving - Calories: 180kcal | Fat: 0.00g | Carbs: '
#                       '52.00g | Protein: 0.00g',
#   'food_id': '96824',
#   'food_name': 'Dr Pepper (16 oz)',
#   'food_type': 'Brand',
#   'food_url': 'https://www.fatsecret.com/calories-nutrition/arbys/dr-pepper-(16-oz)'},
#  {'food_description': 'Per 100g - Calories: 38kcal | Fat: 0.01g | Carbs: 9.77g '
#                       '| Protein: 0.07g',
#   'food_id': '387673',
#   'food_name': 'Soda',
#   'food_type': 'Generic',
#   'food_url': 'https://www.fatsecret.com/calories-nutrition/generic/soda'},
#  {'brand_name': 'Coca-Cola',
#   'food_description': 'Per 1 can - Calories: 0kcal | Fat: 0.00g | Carbs: 0.00g '
#                       '| Protein: 0.00g',
#   'food_id': '51878',
#   'food_name': 'Diet Coke (Can)',
#   'food_type': 'Brand',
#   'food_url': 'https://www.fatsecret.com/calories-nutrition/coca-cola/diet-coke-(can)'},
#  {'brand_name': 'Coca-Cola',
#   'food_description': 'Per 8 fl oz - Calories: 0kcal | Fat: 0.00g | Carbs: '
#                       '0.00g | Protein: 0.00g',
#   'food_id': '43580',
#   'food_name': 'Coke Zero',
#   'food_type': 'Brand',
#   'food_url': 'https://www.fatsecret.com/calories-nutrition/coca-cola/coke-zero/240-ml'},
#  {'brand_name': 'Sunkist',
#   'food_description': 'Per 1 can - Calories: 0kcal | Fat: 0.00g | Carbs: 0.00g '
#                       '| Protein: 0.00g',
#   'food_id': '62488',
#   'food_name': 'Diet Orange Soda (Can)',
#   'food_type': 'Brand',
#   'food_url': 'https://www.fatsecret.com/calories-nutrition/sunkist/diet-orange-soda-(can)'},
#  {'brand_name': 'Chick-fil-A',
#   'food_description': 'Per 1 serving - Calories: 180kcal | Fat: 0.00g | Carbs: '
#                       '48.00g | Protein: 0.00g',
#   'food_id': '60152',
#   'food_name': 'Dr Pepper (Medium)',
#   'food_type': 'Brand',
#   'food_url': 'https://www.fatsecret.com/calories-nutrition/chick-fil-a/dr-pepper-(medium)'},
#  {'brand_name': 'Coca-Cola',
#   'food_description': 'Per 1 can - Calories: 140kcal | Fat: 0.00g | Carbs: '
#                       '38.00g | Protein: 0.00g',
#   'food_id': '94773',
#   'food_name': 'Sprite (Can)',
#   'food_type': 'Brand',
#   'food_url': 'https://www.fatsecret.com/calories-nutrition/coca-cola/sprite-(can)'},
#  {'brand_name': 'Burger King',
#   'food_description': 'Per 1 serving - Calories: 380kcal | Fat: 0.00g | Carbs: '
#                       '102.00g | Protein: 0.00g',
#   'food_id': '105098',
#   'food_name': 'Coca Cola Classic (Large)',
#   'food_type': 'Brand',
#   'food_url': 'https://www.fatsecret.com/calories-nutrition/burger-king/coca-cola-classic-(large)'},
#  {'brand_name': 'Mug',
#   'food_description': 'Per 8 fl oz - Calories: 0kcal | Fat: 0.00g | Carbs: '
#                       '0.00g | Protein: 0.00g',
#   'food_id': '76863',
#   'food_name': 'Diet Cream Soda',
#   'food_type': 'Brand',
#   'food_url': 'https://www.fatsecret.com/calories-nutrition/mug/diet-cream-soda'},
#  {'brand_name': 'Kroger',
#   'food_description': 'Per 1 can - Calories: 160kcal | Fat: 0.00g | Carbs: '
#                       '41.00g | Protein: 0.00g',
#   'food_id': '133981',
#   'food_name': 'Big K Cola (Can)',
#   'food_type': 'Brand',
#   'food_url': 'https://www.fatsecret.com/calories-nutrition/kroger/big-k-cola-(can)'},
#  {'brand_name': 'KFC',
#   'food_description': 'Per 1 serving - Calories: 280kcal | Fat: 0.00g | Carbs: '
#                       '73.00g | Protein: 0.00g',
#   'food_id': '130495',
#   'food_name': 'Mountain Dew (20 oz)',
#   'food_type': 'Brand',
#   'food_url': 'https://www.fatsecret.com/calories-nutrition/kfc/mountain-dew-(20-oz)'},
#  {'brand_name': 'Dr. Pepper',
#   'food_description': 'Per 1 can - Calories: 0kcal | Fat: 0.00g | Carbs: 0.00g '
#                       '| Protein: 0.00g',
#   'food_id': '66137',
#   'food_name': 'Diet Dr. Pepper (Can)',
#   'food_type': 'Brand',
#   'food_url': 'https://www.fatsecret.com/calories-nutrition/dr-pepper/diet-dr-pepper-(can)'}]

# %%
pprint(fs.foods_search("dairy"))
# Out:
# [{'brand_name': 'Neuro',
#   'food_description': 'Per 1 bottle - Calories: 35kcal | Fat: 0.00g | Carbs: '
#                       '9.00g | Protein: 0.00g',
#   'food_id': '7276348',
#   'food_name': 'Daily',
#   'food_type': 'Brand',
#   'food_url': 'https://www.fatsecret.com/calories-nutrition/neuro/daily'},
#  {'brand_name': 'Nutrilite',
#   'food_description': 'Per 1 tablet - Calories: 0kcal | Fat: 0.00g | Carbs: '
#                       '0.00g | Protein: 0.00g',
#   'food_id': '23975373',
#   'food_name': 'Daily',
#   'food_type': 'Brand',
#   'food_url': 'https://www.fatsecret.com/calories-nutrition/nutrilite/daily'},
#  {'brand_name': 'Dairy Fresh',
#   'food_description': 'Per 1 tbsp - Calories: 10kcal | Fat: 1.00g | Carbs: '
#                       '0.00g | Protein: 0.00g',
#   'food_id': '1533847',
#   'food_name': 'Non Dairy Creamer',
#   'food_type': 'Brand',
#   'food_url': 'https://www.fatsecret.com/calories-nutrition/dairy-fresh/non-dairy-creamer'},
#  {'brand_name': "Cadbury's",
#   'food_description': 'Per 1 bar (6 squares) - Calories: 240kcal | Fat: 14.00g '
#                       '| Carbs: 23.00g | Protein: 3.00g',
#   'food_id': '4712828',
#   'food_name': 'Dairy Milk Hazelnut',
#   'food_type': 'Brand',
#   'food_url': 'https://www.fatsecret.com/calories-nutrition/cadburys/dairy-milk-hazelnut'},
#  {'brand_name': "Reese's",
#   'food_description': 'Per 2 tbsp - Calories: 15kcal | Fat: 1.00g | Carbs: '
#                       '0.00g | Protein: 0.00g',
#   'food_id': '28186321',
#   'food_name': 'Dairy Whipped Topping',
#   'food_type': 'Brand',
#   'food_url': 'https://www.fatsecret.com/calories-nutrition/reeses/dairy-whipped-topping'},
#  {'brand_name': 'Crystal Farms',
#   'food_description': 'Per 2 tbsp - Calories: 15kcal | Fat: 1.00g | Carbs: '
#                       '1.00g | Protein: 0.00g',
#   'food_id': '20428083',
#   'food_name': 'Dairy Whipped Topping',
#   'food_type': 'Brand',
#   'food_url': 'https://www.fatsecret.com/calories-nutrition/crystal-farms/dairy-whipped-topping'},
#  {'brand_name': "Trader Joe's",
#   'food_description': 'Per 1 piece - Calories: 100kcal | Fat: 4.00g | Carbs: '
#                       '23.00g | Protein: 0.00g',
#   'food_id': '1690471',
#   'food_name': 'Dairy-Free Mochi',
#   'food_type': 'Brand',
#   'food_url': 'https://www.fatsecret.com/calories-nutrition/trader-joes/dairy-free-mochi'},
#  {'brand_name': "Cadbury's",
#   'food_description': 'Per 1 bar - Calories: 100kcal | Fat: 5.00g | Carbs: '
#                       '11.00g | Protein: 1.00g',
#   'food_id': '2814744',
#   'food_name': 'Dairy Milk Thins',
#   'food_type': 'Brand',
#   'food_url': 'https://www.fatsecret.com/calories-nutrition/cadburys/dairy-milk-thins'},
#  {'brand_name': "Kim's",
#   'food_description': 'Per 2 tbsp - Calories: 58kcal | Fat: 0.00g | Carbs: '
#                       '0.00g | Protein: 0.00g',
#   'food_id': '3102598',
#   'food_name': 'Dairy Free Ranch Dressing',
#   'food_type': 'Brand',
#   'food_url': 'https://www.fatsecret.com/calories-nutrition/kims/dairy-free-ranch-dressing'},
#  {'brand_name': 'Wayfare',
#   'food_description': 'Per 2 tbsp - Calories: 35kcal | Fat: 3.00g | Carbs: '
#                       '2.00g | Protein: 0.00g',
#   'food_id': '19153777',
#   'food_name': 'Dairy Free Sour Cream',
#   'food_type': 'Brand',
#   'food_url': 'https://www.fatsecret.com/calories-nutrition/wayfare/dairy-free-sour-cream'},
#  {'brand_name': 'Good Karma',
#   'food_description': 'Per 1 container - Calories: 130kcal | Fat: 2.00g | '
#                       'Carbs: 24.00g | Protein: 5.00g',
#   'food_id': '17991311',
#   'food_name': 'Dairy Free Strawberry Yogurt',
#   'food_type': 'Brand',
#   'food_url': 'https://www.fatsecret.com/calories-nutrition/good-karma/dairy-free-strawberry-yogurt'},
#  {'brand_name': 'Follow Your Heart',
#   'food_description': 'Per 1 oz - Calories: 80kcal | Fat: 7.00g | Carbs: 6.00g '
#                       '| Protein: 0.00g',
#   'food_id': '29779707',
#   'food_name': 'Dairy-Free Cheddar Shreds',
#   'food_type': 'Brand',
#   'food_url': 'https://www.fatsecret.com/calories-nutrition/follow-your-heart/dairy-free-cheddar-shreds'},
#  {'brand_name': "Cadbury's",
#   'food_description': 'Per 1 bar - Calories: 205kcal | Fat: 11.70g | Carbs: '
#                       '22.30g | Protein: 2.90g',
#   'food_id': '79724',
#   'food_name': 'Dairy Milk Chocolate Bar',
#   'food_type': 'Brand',
#   'food_url': 'https://www.fatsecret.com/calories-nutrition/cadburys/dairy-milk-chocolate-bar'},
#  {'brand_name': 'Smart Balance',
#   'food_description': 'Per 1 tbsp  - Calories: 90kcal | Fat: 10.00g | Carbs: '
#                       '0.00g | Protein: 0.00g',
#   'food_id': '10278640',
#   'food_name': 'Dairy Free Butter Original',
#   'food_type': 'Brand',
#   'food_url': 'https://www.fatsecret.com/calories-nutrition/smart-balance/dairy-free-butter-original'},
#  {'brand_name': "Cadbury's",
#   'food_description': 'Per 1 bar - Calories: 260kcal | Fat: 14.60g | Carbs: '
#                       '27.90g | Protein: 3.70g',
#   'food_id': '49039',
#   'food_name': 'Dairy Milk Candy Bar',
#   'food_type': 'Brand',
#   'food_url': 'https://www.fatsecret.com/calories-nutrition/cadburys/dairy-milk-candy-bar'},
#  {'brand_name': 'Pure',
#   'food_description': 'Per 1 serving - Calories: 600kcal | Fat: 67.00g | '
#                       'Carbs: 0.00g | Protein: 0.00g',
#   'food_id': '995863',
#   'food_name': 'Dairy Free Sunflower Spread',
#   'food_type': 'Brand',
#   'food_url': 'https://www.fatsecret.com/calories-nutrition/pure/dairy-free-sunflower-spread'},
#  {'brand_name': 'Silk',
#   'food_description': 'Per 1 tbsp - Calories: 15kcal | Fat: 1.50g | Carbs: '
#                       '0.00g | Protein: 0.00g',
#   'food_id': '33437784',
#   'food_name': 'Dairy Free Half & Half',
#   'food_type': 'Brand',
#   'food_url': 'https://www.fatsecret.com/calories-nutrition/silk/dairy-free-half-half'},
#  {'brand_name': "Vegan Rob's",
#   'food_description': 'Per 1 oz - Calories: 140kcal | Fat: 8.00g | Carbs: '
#                       '18.00g | Protein: 2.00g',
#   'food_id': '28041825',
#   'food_name': 'Dairy Free Cheddar Puffs',
#   'food_type': 'Brand',
#   'food_url': 'https://www.fatsecret.com/calories-nutrition/vegan-robs/dairy-free-cheddar-puffs'},
#  {'brand_name': 'Banana Wave',
#   'food_description': 'Per 1 cup - Calories: 150kcal | Fat: 5.00g | Carbs: '
#                       '22.00g | Protein: 4.00g',
#   'food_id': '24490615',
#   'food_name': 'Dairy Free Banana Milk',
#   'food_type': 'Brand',
#   'food_url': 'https://www.fatsecret.com/calories-nutrition/banana-wave/dairy-free-banana-milk'},
#  {'brand_name': "Road's End Organics",
#   'food_description': 'Per 1 cup  - Calories: 330kcal | Fat: 1.00g | Carbs: '
#                       '62.00g | Protein: 14.00g',
#   'food_id': '893229',
#   'food_name': 'Dairy Free Shells & Chreese',
#   'food_type': 'Brand',
#   'food_url': 'https://www.fatsecret.com/calories-nutrition/roads-end-organics/dairy-free-shells-and-chreese'}]

# %%
pprint(fs.foods_search("sugar"))
# Out:
# [{'food_description': 'Per 100g - Calories: 387kcal | Fat: 0.00g | Carbs: '
#                       '99.98g | Protein: 0.00g',
#   'food_id': '7175',
#   'food_name': 'Sugar',
#   'food_type': 'Generic',
#   'food_url': 'https://www.fatsecret.com/calories-nutrition/generic/sugar'},
#  {'food_description': 'Per 100g - Calories: 387kcal | Fat: 0.00g | Carbs: '
#                       '99.98g | Protein: 0.00g',
#   'food_id': '39559',
#   'food_name': 'Granulated Sugar',
#   'food_type': 'Generic',
#   'food_url': 'https://www.fatsecret.com/calories-nutrition/usda/granulated-sugar'},
#  {'brand_name': 'Domino Sugar',
#   'food_description': 'Per 1 tsp - Calories: 15kcal | Fat: 0.00g | Carbs: '
#                       '4.00g | Protein: 0.00g',
#   'food_id': '90477',
#   'food_name': 'Granulated Sugar',
#   'food_type': 'Brand',
#   'food_url': 'https://www.fatsecret.com/calories-nutrition/domino-sugar/granulated-sugar'},
#  {'food_description': 'Per 100g - Calories: 377kcal | Fat: 0.00g | Carbs: '
#                       '97.33g | Protein: 0.00g',
#   'food_id': '7107',
#   'food_name': 'Sugar',
#   'food_type': 'Generic',
#   'food_url': 'https://www.fatsecret.com/calories-nutrition/generic/sugar-raw'},
#  {'brand_name': 'Great Value',
#   'food_description': 'Per 1 tsp - Calories: 15kcal | Fat: 0.00g | Carbs: '
#                       '4.00g | Protein: 0.00g',
#   'food_id': '59263',
#   'food_name': 'Pure Cane Sugar',
#   'food_type': 'Brand',
#   'food_url': 'https://www.fatsecret.com/calories-nutrition/great-value/pure-cane-sugar'},
#  {'brand_name': 'Domino Sugar',
#   'food_description': 'Per 1 packet - Calories: 15kcal | Fat: 0.00g | Carbs: '
#                       '4.00g | Protein: 0.00g',
#   'food_id': '5093550',
#   'food_name': 'Sugar Packet',
#   'food_type': 'Brand',
#   'food_url': 'https://www.fatsecret.com/calories-nutrition/domino-sugar/sugar-packet'},
#  {'food_description': 'Per 615g - Calories: 775kcal | Fat: 0.00g | Carbs: '
#                       '199.98g | Protein: 0.00g',
#   'food_id': '7367',
#   'food_name': 'White Sugar and Water Syrup',
#   'food_type': 'Generic',
#   'food_url': 'https://www.fatsecret.com/calories-nutrition/generic/sugar-(white)-and-water-syrup'},
#  {'brand_name': 'Sugar in the Raw',
#   'food_description': 'Per 1 tsp - Calories: 15kcal | Fat: 0.00g | Carbs: '
#                       '4.00g | Protein: 0.00g',
#   'food_id': '793278',
#   'food_name': 'Natural Cane Turbinado Sugar',
#   'food_type': 'Brand',
#   'food_url': 'https://www.fatsecret.com/calories-nutrition/sugar-in-the-raw/natural-cane-turbinado-sugar'},
#  {'brand_name': 'C&H',
#   'food_description': 'Per 1 tsp - Calories: 15kcal | Fat: 0.00g | Carbs: '
#                       '4.00g | Protein: 0.00g',
#   'food_id': '102086',
#   'food_name': 'Granulated White Pure Cane Sugar',
#   'food_type': 'Brand',
#   'food_url': 'https://www.fatsecret.com/calories-nutrition/candh/granulated-white-pure-cane-sugar'},
#  {'food_description': 'Per 100g - Calories: 377kcal | Fat: 0.00g | Carbs: '
#                       '97.33g | Protein: 0.00g',
#   'food_id': '39558',
#   'food_name': 'Brown Sugar',
#   'food_type': 'Generic',
#   'food_url': 'https://www.fatsecret.com/calories-nutrition/usda/brown-sugar'},
#  {'brand_name': '365',
#   'food_description': 'Per 1 tsp - Calories: 15kcal | Fat: 0.00g | Carbs: '
#                       '4.00g | Protein: 0.00g',
#   'food_id': '1086753',
#   'food_name': 'Organic Cane Sugar',
#   'food_type': 'Brand',
#   'food_url': 'https://www.fatsecret.com/calories-nutrition/365/organic-cane-sugar'},
#  {'brand_name': 'Domino Sugar',
#   'food_description': 'Per 1/4 cup - Calories: 120kcal | Fat: 0.00g | Carbs: '
#                       '30.00g | Protein: 0.00g',
#   'food_id': '265001',
#   'food_name': 'Confectioners Sugar',
#   'food_type': 'Brand',
#   'food_url': 'https://www.fatsecret.com/calories-nutrition/domino-sugar/confectioners-sugar'},
#  {'food_description': 'Per 100g - Calories: 387kcal | Fat: 0.00g | Carbs: '
#                       '99.98g | Protein: 0.00g',
#   'food_id': '7105',
#   'food_name': 'White Sugar (Granulated or Lump)',
#   'food_type': 'Generic',
#   'food_url': 'https://www.fatsecret.com/calories-nutrition/generic/sugar-white-granulated-or-lump'},
#  {'brand_name': "Trader Joe's",
#   'food_description': 'Per 1 tsp - Calories: 15kcal | Fat: 0.00g | Carbs: '
#                       '4.00g | Protein: 0.00g',
#   'food_id': '135244',
#   'food_name': 'Organic Turbinado Raw Cane Sugar',
#   'food_type': 'Brand',
#   'food_url': 'https://www.fatsecret.com/calories-nutrition/trader-joes/organic-turbinado-raw-cane-sugar'},
#  {'brand_name': "Wendy's",
#   'food_description': 'Per 1 packet - Calories: 50kcal | Fat: 0.00g | Carbs: '
#                       '12.00g | Protein: 0.00g',
#   'food_id': '286625',
#   'food_name': 'Sugar',
#   'food_type': 'Brand',
#   'food_url': 'https://www.fatsecret.com/calories-nutrition/wendys/sugar'},
#  {'food_description': 'Per 100g - Calories: 389kcal | Fat: 0.10g | Carbs: '
#                       '99.60g | Protein: 0.00g',
#   'food_id': '39560',
#   'food_name': 'Powdered Sugar',
#   'food_type': 'Generic',
#   'food_url': 'https://www.fatsecret.com/calories-nutrition/usda/powdered-sugar'},
#  {'brand_name': 'Shurfine',
#   'food_description': 'Per 1 tbsp - Calories: 15kcal | Fat: 0.00g | Carbs: '
#                       '4.00g | Protein: 0.00g',
#   'food_id': '2391498',
#   'food_name': 'Light Brown Sugar',
#   'food_type': 'Brand',
#   'food_url': 'https://www.fatsecret.com/calories-nutrition/shurfine/light-brown-sugar'},
#  {'brand_name': 'Wegmans',
#   'food_description': 'Per 1 tsp - Calories: 15kcal | Fat: 0.00g | Carbs: '
#                       '4.00g | Protein: 0.00g',
#   'food_id': '102253',
#   'food_name': 'Dark Brown Sugar',
#   'food_type': 'Brand',
#   'food_url': 'https://www.fatsecret.com/calories-nutrition/wegmans/dark-brown-sugar'},
#  {'brand_name': 'C&H',
#   'food_description': 'Per 1 packet - Calories: 5kcal | Fat: 0.00g | Carbs: '
#                       '2.00g | Protein: 0.00g',
#   'food_id': '3968387',
#   'food_name': 'Sugar & Stevia Blend',
#   'food_type': 'Brand',
#   'food_url': 'https://www.fatsecret.com/calories-nutrition/candh/sugar-and-stevia-blend'},
#  {'brand_name': 'Sweet Additions',
#   'food_description': 'Per 1 packet - Calories: 0kcal | Fat: 0.00g | Carbs: '
#                       '2.00g | Protein: 0.00g',
#   'food_id': '3550767',
#   'food_name': 'Stevia',
#   'food_type': 'Brand',
#   'food_url': 'https://www.fatsecret.com/calories-nutrition/sweet-additions/stevia'}]

# %%
pprint(fs.foods_search("Tacos"))
# Out:
# [{'food_description': 'Per 78g - Calories: 221kcal | Fat: 12.65g | Carbs: '
#                       '16.20g | Protein: 10.88g',
#   'food_id': '4823',
#   'food_name': 'Taco or Tostada with Beef, Cheese and Lettuce',
#   'food_type': 'Generic',
#   'food_url': 'https://www.fatsecret.com/calories-nutrition/generic/taco-or-tostada-with-beef-cheese-and-lettuce'},
#  {'food_description': 'Per 76g - Calories: 158kcal | Fat: 9.36g | Carbs: '
#                       '10.01g | Protein: 8.83g',
#   'food_id': '4825',
#   'food_name': 'Taco or Tostada with Beef, Cheese, Lettuce, Tomato and Salsa',
#   'food_type': 'Generic',
#   'food_url': 'https://www.fatsecret.com/calories-nutrition/generic/taco-or-tostada-with-beef-cheese-lettuce-tomato-and-salsa'},
#  {'food_description': 'Per 100g - Calories: 246kcal | Fat: 13.23g | Carbs: '
#                       '19.37g | Protein: 11.87g',
#   'food_id': '4826',
#   'food_name': 'Soft Taco with Beef, Cheese, Lettuce, Tomato and Sour Cream',
#   'food_type': 'Generic',
#   'food_url': 'https://www.fatsecret.com/calories-nutrition/generic/soft-taco-with-beef-cheese-lettuce-tomato-and-sour-cream'},
#  {'food_description': 'Per 71g - Calories: 199kcal | Fat: 9.03g | Carbs: '
#                       '18.26g | Protein: 10.44g',
#   'food_id': '4827',
#   'food_name': 'Soft Taco with Beef, Cheese and Lettuce',
#   'food_type': 'Generic',
#   'food_url': 'https://www.fatsecret.com/calories-nutrition/generic/soft-taco-with-beef-cheese-and-lettuce'},
#  {'brand_name': 'Old El Paso',
#   'food_description': 'Per 2 shells, 2 tsp seasoning mix, 1 tbsp taco sauce - '
#                       'Calories: 250kcal | Fat: 5.00g | Carbs: 17.00g | '
#                       'Protein: 2.00g',
#   'food_id': '215775',
#   'food_name': 'Taco Dinner Kit prepared with Lean Ground Meat',
#   'food_type': 'Brand',
#   'food_url': 'https://www.fatsecret.com/calories-nutrition/old-el-paso/taco-dinner-kit-prepared-with-lean-ground-meat'},
#  {'food_description': 'Per 73g - Calories: 116kcal | Fat: 4.83g | Carbs: 9.92g '
#                       '| Protein: 8.53g',
#   'food_id': '4830',
#   'food_name': 'Taco or Tostada with Chicken or Turkey, Lettuce, Tomato and '
#                'Salsa',
#   'food_type': 'Generic',
#   'food_url': 'https://www.fatsecret.com/calories-nutrition/generic/taco-or-tostada-with-chicken-or-turkey-lettuce-tomato-and-salsa'},
#  {'brand_name': 'Taco Bell',
#   'food_description': 'Per 1 taco  - Calories: 170kcal | Fat: 9.00g | Carbs: '
#                       '13.00g | Protein: 8.00g',
#   'food_id': '44955',
#   'food_name': 'Crunchy Taco',
#   'food_type': 'Brand',
#   'food_url': 'https://www.fatsecret.com/calories-nutrition/taco-bell/crunchy-taco'},
#  {'food_description': 'Per 69g - Calories: 130kcal | Fat: 7.03g | Carbs: 9.92g '
#                       '| Protein: 7.07g',
#   'food_id': '4824',
#   'food_name': 'Taco or Tostada with Beef, Lettuce, Tomato and Salsa',
#   'food_type': 'Generic',
#   'food_url': 'https://www.fatsecret.com/calories-nutrition/generic/taco-or-tostada-with-beef-lettuce-tomato-and-salsa'},
#  {'food_description': 'Per 100g - Calories: 216kcal | Fat: 12.02g | Carbs: '
#                       '15.63g | Protein: 12.08g',
#   'food_id': '39919',
#   'food_name': 'Taco',
#   'food_type': 'Generic',
#   'food_url': 'https://www.fatsecret.com/calories-nutrition/usda/taco'},
#  {'brand_name': 'Del Taco',
#   'food_description': 'Per 1 taco - Calories: 230kcal | Fat: 10.00g | Carbs: '
#                       '20.00g | Protein: 10.00g',
#   'food_id': '49692',
#   'food_name': 'Carne Asada Taco',
#   'food_type': 'Brand',
#   'food_url': 'https://www.fatsecret.com/calories-nutrition/del-taco/carne-asada-taco'},
#  {'food_description': 'Per 102g - Calories: 220kcal | Fat: 10.25g | Carbs: '
#                       '19.73g | Protein: 11.66g',
#   'food_id': '4832',
#   'food_name': 'Soft Taco with Beef, Cheese, Lettuce, Tomato and Salsa',
#   'food_type': 'Generic',
#   'food_url': 'https://www.fatsecret.com/calories-nutrition/generic/soft-taco-with-beef-cheese-lettuce-tomato-and-salsa'},
#  {'food_description': 'Per 128g - Calories: 247kcal | Fat: 8.76g | Carbs: '
#                       '18.70g | Protein: 22.08g',
#   'food_id': '4828',
#   'food_name': 'Soft Taco with Chicken, Cheese and Lettuce',
#   'food_type': 'Generic',
#   'food_url': 'https://www.fatsecret.com/calories-nutrition/generic/soft-taco-with-chicken-cheese-and-lettuce'},
#  {'brand_name': 'Del Taco',
#   'food_description': 'Per 1 taco - Calories: 130kcal | Fat: 7.00g | Carbs: '
#                       '9.00g | Protein: 7.00g',
#   'food_id': '49654',
#   'food_name': 'Taco',
#   'food_type': 'Brand',
#   'food_url': 'https://www.fatsecret.com/calories-nutrition/del-taco/taco'},
#  {'food_description': 'Per 80g - Calories: 145kcal | Fat: 7.16g | Carbs: '
#                       '10.01g | Protein: 10.28g',
#   'food_id': '4831',
#   'food_name': 'Taco or Tostada with Chicken, Cheese, Lettuce, Tomato and '
#                'Salsa',
#   'food_type': 'Generic',
#   'food_url': 'https://www.fatsecret.com/calories-nutrition/generic/taco-or-tostada-with-chicken-cheese-lettuce-tomato-and-salsa'},
#  {'brand_name': 'Qdoba Mexican Grill',
#   'food_description': 'Per 1 taco - Calories: 160kcal | Fat: 3.50g | Carbs: '
#                       '19.00g | Protein: 8.00g',
#   'food_id': '67042',
#   'food_name': 'Shredded Pork Taco',
#   'food_type': 'Brand',
#   'food_url': 'https://www.fatsecret.com/calories-nutrition/qdoba-mexican-grill/shredded-pork-taco'},
#  {'brand_name': "Rubio's Fresh Mexican Grill",
#   'food_description': 'Per 1 taco - Calories: 90kcal | Fat: 2.50g | Carbs: '
#                       '9.00g | Protein: 8.00g',
#   'food_id': '57734',
#   'food_name': 'Chicken Street Taco',
#   'food_type': 'Brand',
#   'food_url': 'https://www.fatsecret.com/calories-nutrition/rubios-fresh-mexican-grill/chicken-street-taco'},
#  {'brand_name': 'Chipotle Mexican Grill',
#   'food_description': 'Per 4 tacos - Calories: 710kcal | Fat: 37.00g | Carbs: '
#                       '83.00g | Protein: 10.00g',
#   'food_id': '103180',
#   'food_name': 'Carnitas Tacos (Cheese, Tomato Salsa, Lettuce and Sour Cream)',
#   'food_type': 'Brand',
#   'food_url': 'https://www.fatsecret.com/calories-nutrition/chipotle-mexican-grill/carnitas-tacos-(cheese-tomato-salsa-lettuce-and-sour-cream)'},
#  {'brand_name': 'Taco Del Mar',
#   'food_description': 'Per 1 taco - Calories: 280kcal | Fat: 11.00g | Carbs: '
#                       '28.00g | Protein: 18.00g',
#   'food_id': '66004',
#   'food_name': 'Beef Soft Taco',
#   'food_type': 'Brand',
#   'food_url': 'https://www.fatsecret.com/calories-nutrition/taco-del-mar/beef-soft-taco'},
#  {'food_description': 'Per 86g - Calories: 156kcal | Fat: 8.13g | Carbs: '
#                       '12.99g | Protein: 8.41g',
#   'food_id': '4836',
#   'food_name': 'Taco or Tostada with Beans, Cheese, Meat, Lettuce, Tomato and '
#                'Salsa',
#   'food_type': 'Generic',
#   'food_url': 'https://www.fatsecret.com/calories-nutrition/generic/taco-or-tostada-with-beans-cheese-meat-lettuce-tomato-and-salsa'},
#  {'brand_name': 'Del Taco',
#   'food_description': 'Per 1 taco - Calories: 150kcal | Fat: 6.00g | Carbs: '
#                       '15.00g | Protein: 8.00g',
#   'food_id': '88729',
#   'food_name': 'Soft Taco',
#   'food_type': 'Brand',
#   'food_url': 'https://www.fatsecret.com/calories-nutrition/del-taco/soft-taco'}]

# %%
pprint(fs.foods_search("vegetables"))
# Out:
# [{'food_description': 'Per 169g - Calories: 84kcal | Fat: 0.27g | Carbs: '
#                       '18.79g | Protein: 5.85g',
#   'food_id': '6332',
#   'food_name': 'Cooked Vegetables (from Fresh, Fat Not Added in Cooking)',
#   'food_type': 'Generic',
#   'food_url': 'https://www.fatsecret.com/calories-nutrition/generic/artichoke-globe-(french)-cooked-from-fresh-fat-not-added-in-cooking'},
#  {'brand_name': 'Great Value',
#   'food_description': 'Per 1/2 cup - Calories: 50kcal | Fat: 0.00g | Carbs: '
#                       '10.00g | Protein: 1.00g',
#   'food_id': '89567',
#   'food_name': 'Vegetable Medley',
#   'food_type': 'Brand',
#   'food_url': 'https://www.fatsecret.com/calories-nutrition/great-value/vegetable-medley'},
#  {'brand_name': 'Birds Eye',
#   'food_description': 'Per 1 cup - Calories: 30kcal | Fat: 0.00g | Carbs: '
#                       '5.00g | Protein: 1.00g',
#   'food_id': '86834',
#   'food_name': 'Steamfresh Broccoli, Cauliflower & Carrots',
#   'food_type': 'Brand',
#   'food_url': 'https://www.fatsecret.com/calories-nutrition/birds-eye/steamfresh-broccoli-cauliflower-carrots'},
#  {'food_description': 'Per 441g - Calories: 273kcal | Fat: 1.50g | Carbs: '
#                       '58.11g | Protein: 13.48g',
#   'food_id': '6875',
#   'food_name': 'Cooked Vegetable Combination with Soy-Based Sauce',
#   'food_type': 'Generic',
#   'food_url': 'https://www.fatsecret.com/calories-nutrition/generic/vegetable-combination-(excluding-carrots-broccoli-and-dark-green-leafy)-cooked-with-soy-based-sauce'},
#  {'food_description': 'Per 100g - Calories: 64kcal | Fat: 0.52g | Carbs: '
#                       '13.46g | Protein: 3.33g',
#   'food_id': '36664',
#   'food_name': 'Mixed Vegetables (Frozen)',
#   'food_type': 'Generic',
#   'food_url': 'https://www.fatsecret.com/calories-nutrition/usda/mixed-vegetables-(frozen)'},
#  {'food_description': 'Per 169g - Calories: 113kcal | Fat: 4.13g | Carbs: '
#                       '15.18g | Protein: 4.23g',
#   'food_id': '6650',
#   'food_name': 'Cooked Mixed Vegetables (Corn, Lima Beans, Peas, Green Beans '
#                'and Carrots, Canned)',
#   'food_type': 'Generic',
#   'food_url': 'https://www.fatsecret.com/calories-nutrition/generic/mixed-vegetables-(corn-lima-beans-peas-green-beans-and-carrots)-cooked-from-canned'},
#  {'food_description': 'Per 100g - Calories: 41kcal | Fat: 0.24g | Carbs: 9.58g '
#                       '| Protein: 0.93g',
#   'food_id': '36320',
#   'food_name': 'Carrots',
#   'food_type': 'Generic',
#   'food_url': 'https://www.fatsecret.com/calories-nutrition/usda/carrots'},
#  {'brand_name': 'Great Value',
#   'food_description': 'Per 1 cup - Calories: 70kcal | Fat: 0.00g | Carbs: '
#                       '12.00g | Protein: 2.00g',
#   'food_id': '90661',
#   'food_name': 'In The Bag Steamable Vegetables - Mixed Garden Medley',
#   'food_type': 'Brand',
#   'food_url': 'https://www.fatsecret.com/calories-nutrition/great-value/in-the-bag-steamable-vegetables---mixed-garden-medley'},
#  {'food_description': 'Per 100g - Calories: 20kcal | Fat: 0.17g | Carbs: 4.64g '
#                       '| Protein: 0.86g',
#   'food_id': '36480',
#   'food_name': 'Green Peppers',
#   'food_type': 'Generic',
#   'food_url': 'https://www.fatsecret.com/calories-nutrition/usda/green-peppers'},
#  {'food_description': 'Per 100g - Calories: 34kcal | Fat: 0.37g | Carbs: 6.64g '
#                       '| Protein: 2.82g',
#   'food_id': '36291',
#   'food_name': 'Broccoli',
#   'food_type': 'Generic',
#   'food_url': 'https://www.fatsecret.com/calories-nutrition/usda/broccoli'},
#  {'food_description': 'Per 100g - Calories: 18kcal | Fat: 0.20g | Carbs: 3.92g '
#                       '| Protein: 0.88g',
#   'food_id': '6138',
#   'food_name': 'Tomatoes',
#   'food_type': 'Generic',
#   'food_url': 'https://www.fatsecret.com/calories-nutrition/generic/tomatoes-raw'},
#  {'food_description': 'Per 100g - Calories: 42kcal | Fat: 0.08g | Carbs: '
#                       '10.11g | Protein: 0.92g',
#   'food_id': '36442',
#   'food_name': 'Onions',
#   'food_type': 'Generic',
#   'food_url': 'https://www.fatsecret.com/calories-nutrition/usda/onions'},
#  {'food_description': 'Per 100g - Calories: 22kcal | Fat: 0.34g | Carbs: 3.28g '
#                       '| Protein: 3.09g',
#   'food_id': '36421',
#   'food_name': 'Mushrooms',
#   'food_type': 'Generic',
#   'food_url': 'https://www.fatsecret.com/calories-nutrition/usda/mushrooms'},
#  {'food_description': 'Per 100g - Calories: 16kcal | Fat: 0.18g | Carbs: 3.35g '
#                       '| Protein: 1.21g',
#   'food_id': '36590',
#   'food_name': 'Zucchini',
#   'food_type': 'Generic',
#   'food_url': 'https://www.fatsecret.com/calories-nutrition/usda/zucchini'},
#  {'food_description': 'Per 100g - Calories: 25kcal | Fat: 0.10g | Carbs: 5.30g '
#                       '| Protein: 1.98g',
#   'food_id': '36327',
#   'food_name': 'Cauliflower',
#   'food_type': 'Generic',
#   'food_url': 'https://www.fatsecret.com/calories-nutrition/usda/cauliflower'},
#  {'food_description': 'Per 412g - Calories: 296kcal | Fat: 10.13g | Carbs: '
#                       '41.58g | Protein: 15.27g',
#   'food_id': '6789',
#   'food_name': 'Cooked Vegetable Combinations with Cheese Sauce (Including '
#                'Carrots, Broccoli, and/or Dark-Green Leafy)',
#   'food_type': 'Generic',
#   'food_url': 'https://www.fatsecret.com/calories-nutrition/generic/vegetable-combinations-(including-carrots-broccoli-and-or-dark-green-leafy)-cooked-with-cheese-sauce'},
#  {'food_description': 'Per 100g - Calories: 12kcal | Fat: 0.16g | Carbs: 2.16g '
#                       '| Protein: 0.59g',
#   'food_id': '36377',
#   'food_name': 'Cucumber (Peeled)',
#   'food_type': 'Generic',
#   'food_url': 'https://www.fatsecret.com/calories-nutrition/usda/cucumber-(peeled)'},
#  {'food_description': 'Per 100g - Calories: 13kcal | Fat: 0.20g | Carbs: 2.18g '
#                       '| Protein: 1.50g',
#   'food_id': '36314',
#   'food_name': 'Chinese Cabbage (Bok-Choy, Pak-Choi)',
#   'food_type': 'Generic',
#   'food_url': 'https://www.fatsecret.com/calories-nutrition/usda/chinese-cabbage-(bok-choy-pak-choi)'},
#  {'food_description': 'Per 100g - Calories: 14kcal | Fat: 0.17g | Carbs: 2.97g '
#                       '| Protein: 0.69g',
#   'food_id': '36333',
#   'food_name': 'Celery',
#   'food_type': 'Generic',
#   'food_url': 'https://www.fatsecret.com/calories-nutrition/usda/celery'},
#  {'food_description': 'Per 100g - Calories: 19kcal | Fat: 0.24g | Carbs: 4.04g '
#                       '| Protein: 0.94g',
#   'food_id': '36583',
#   'food_name': 'Summer Squash (Crookneck and Straightneck)',
#   'food_type': 'Generic',
#   'food_url': 'https://www.fatsecret.com/calories-nutrition/usda/summer-squash-(crookneck-and-straightneck)'}]
