# %%
# %run countries_with_highest_sugar_intake_final.ipynb
# Out:
#    country   2011
# 26  Canada  137.0
#    country   2012
# 26  Canada  132.0
#    country   2013
# 26  Canada  132.0

# %%
# %run SugarVsIncome.ipynb

# %%
# %run BadTeeth_vs_SugarConsumption.ipynb
# Out:
# The correlation coefficient between bad teeth vs sugar consumption is 0.14
# slope = 0.003518, intercept = 1.67, r-value = 0.14, p-value = 0.1, standard error = 0.0

# %%
# %run Obesity_vs_SugarConsumption.ipynb
# Out:
# The correlation coefficient between obesity vs sugar consumption is 0.65
# slope = 0.14, intercept = 5.93, r-value = 0.65, p-value = 0.0, standard error = 0.01

# %%
# %run groceries_final.ipynb

# %% [markdown]
# The API runs by itself, but not on this 'magic' notebook. When we fetch the data of all food groups at the same time, we get a runtime error. We believe this is a result of the restrictions that we get on free data. The API code is in the Master branch titled 'Api_FatSecret'. The code below is representative of the output that is a result of the API.

# %%
import matplotlib as pyplot

categories = ["Whole Milk","Other Vegetable","Rolls","Soda", "Yogurt"]
bars_in_categories = [28,3.65 ,2, 28, 12]
x_axis = np.arange(len(bars_in_categories))
# Create a bar chart based upon the above data
plt.bar(x_axis, bars_in_categories, color="g", align="center" )
#xticks
tick_locations = [value for value in x_axis]
plt.xticks(tick_locations, categories, rotation=45)
plt.title("Sugar Content in Grocery Items")
plt.ylabel("Grams of Sugar")
# Out:
# Text(0, 0.5, 'Grams of Sugar')
